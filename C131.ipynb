# %% [markdown]
# #1.3.1 Basic Operations on Images

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
def pltImage(img):
    plt.imshow(img)
    plt.xticks([]), plt.yticks([])
    plt.show()

# %%
img = cv2.imread('19970714.jpeg')
px = img[100,100]
print(px)
# Out:
# [244 177 102]

# %%
pltImage(img)

# %%
blue = img[100,100,2]
print(blue)
# Out:
# 102

# %%
img[100,100] = [255,255,255]
pltImage(img)

# %%
img.shape
# Out:
# (512, 683, 3)

# %%
img.size
# Out:
# 1049088

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
w = 100
ball = img[402:(402+w),550:(550+w)] # Region of Interest

# %%
pltImage(ball)

# %%
ball = img[10:10+w, 10:10+w]

# %%
pltImage(img)

# %%
b,g,r = cv2.split(img) # RGB Red Green Blue BGR

# %%
b.shape
# Out:
# (512, 683)

# %%
b
# Out:
# array([[236, 237, 237, ..., 253, 252, 251],
#        [236, 236, 237, ..., 252, 251, 250],
#        [233, 234, 234, ..., 252, 251, 250],
#        ...,
#        [ 18,  23,  27, ...,   2,   6,   9],
#        [ 15,   5,   6, ...,   2,   3,   5],
#        [  4,   0,   0, ...,   6,   5,   4]], dtype=uint8)

# %%
g
# Out:
# array([[158, 159, 159, ..., 248, 247, 246],
#        [158, 158, 159, ..., 247, 246, 245],
#        [157, 158, 158, ..., 247, 246, 245],
#        ...,
#        [ 41,  46,  48, ...,   3,   7,  12],
#        [ 36,  26,  23, ...,   2,   3,   5],
#        [ 25,  17,  12, ...,   6,   5,   4]], dtype=uint8)

# %%
r
# Out:
# array([[ 92,  93,  93, ..., 249, 248, 247],
#        [ 92,  92,  93, ..., 248, 247, 246],
#        [ 91,  92,  92, ..., 248, 247, 246],
#        ...,
#        [ 33,  38,  39, ...,   1,   5,  10],
#        [ 27,  17,  14, ...,   2,   3,   5],
#        [ 16,   8,   4, ...,   6,   5,   4]], dtype=uint8)

# %%
img = cv2.merge((r,g,b))

# %%
pltImage(img)

# %%
pltImage(b)

# %%
pltImage(g)

# %%
BLUE = [255,0,0]
img1 = cv2.imread('19970714.jpeg')
replicate = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REPLICATE)
reflect = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REFLECT)
reflect101 = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REFLECT_101)
wrap = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_WRAP)
constant= cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_CONSTANT,value=BLUE)

# %%
plt.subplot(231),plt.imshow(img1,'gray'),plt.title('ORIGINAL')
plt.subplot(232),plt.imshow(replicate,'gray'),plt.title('REPLICATE')
plt.subplot(233),plt.imshow(reflect,'gray'),plt.title('REFLECT')
plt.subplot(234),plt.imshow(reflect101,'gray'),plt.title('REFLECT_101')
plt.subplot(235),plt.imshow(wrap,'gray'),plt.title('WRAP')
plt.subplot(236),plt.imshow(constant,'gray'),plt.title('CONSTANT')
plt.show()
